# %%
import geopandas as gpd

# %%
import zipfile

with zipfile.ZipFile("/content/DHM_KOIN_2021.zip", "r") as z:
    z.extractall("/content/DHM_KOIN_2021")

# %%
lau = gpd.read_file("/content/DHM_KOIN_2021/âåïÄÆêëäæ ëÄêîÄÆåÆäæ/LAU2021.shp")

# %%
lau.head()
lau.crs
lau.columns
# Out:
# Index(['KAL2022', 'LAU_LABEL3', 'Shape_Leng', 'Shape_Le_1', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
lau.crs
# Out:
# <Projected CRS: EPSG:2100>
# Name: GGRS87 / Greek Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Greece - onshore.
# - bounds: (19.57, 34.88, 28.3, 41.75)
# Coordinate Operation:
# - name: Greek Grid
# - method: Transverse Mercator
# Datum: Greek Geodetic Reference System 1987
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
lau["point"] = lau.geometry.representative_point()

# %%
lau["x"] = lau.point.x
lau["y"] = lau.point.y

# %%
lau_points = lau[["KAL2022", "LAU_LABEL3", "x", "y"]]

# %%
lau_points.to_csv("lau_coordinates.csv", index=False)

# %%
# select fields
lau_geojson = lau[["KAL2022", "LAU_LABEL3", "geometry"]]

# geometry is in Greek grid
lau_geojson = lau_geojson.to_crs("EPSG:2100")

# export to GeoJSON
lau_geojson.to_file("lau_boundaries.geojson", driver="GeoJSON")
